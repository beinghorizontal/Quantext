# %% [markdown]
# # Import necessary libraries

# %%
# !pip install yfinance  # to fetch the financial data
# !pip install pandas_ta  # to create the indicators with pandas data frame
# !pip install torch  # we will be using torch as a back end for Keras ==3
# !pip install keras==3.0.0  # Keras 3.0 now supports pytorch as a backend as well
# !pip install livelossplot  # to plot live accuracy and loss plots while training

# %% [markdown]
# Set Torch as backend

# %%
import os
import torch
os.environ["KERAS_BACKEND"] = "torch"

# %% [markdown]
# We will confirm it is using a GPU

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # Import essential libraries

# %%
import yfinance as yf
import datetime
import keras
import numpy as np
import matplotlib.pyplot as plt
from pandas_datareader import data
# from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import plot_model

# %% [markdown]
# # Download the historical data from Yahoo finance for 15 years data, replace  'days=15' to change the years accordingly

# %%
# ticker_symbol = "RELIANCE.NS"
ticker_symbol = "^NSEI"

start_date = datetime.datetime.now() - datetime.timedelta(days=15 * 365)
end_date = datetime.datetime.now()

df1 = yf.download(ticker_symbol, start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# using yfinance download weekly data instead of daily for last 15 years for ticker "^NSEI"
# ticker_symbol = "^NSEI"
# df2 = yf.download(ticker_symbol, period="15y", interval="1wk")

# # drop adjusted close column and volume column
# df2 = df2.drop(['Adj Close', 'Volume'], axis=1)
# #Calculate percentage returns  for df2 
# df2 = df2.pct_change()
# df2 = df2.dropna()
# df2['target'] = (df2['Close'].shift(-1) > 0).astype(int)

# %% [markdown]
# Create a backup copy to reset the experiment

# %%
df = df1.copy()
#df = df2.copy()

# %% [markdown]
# # Alternate method to download historical data You need Alpha Vantage free API key. Store that key in the text folder and replace the path. For this script I have Used  the Yahoo finance data the only difference will be the column name which will be capitalized Or in small letters

# %%
#!pip install pandas-dataloader
#from pandas_datareader import data
# Download stock market data (e.g., Apple Inc.)
# with open('G:/anaconda/Scripts/data/alpha_vantage/key.txt', 'r') as f:
#     key = f.read()
# symbol = 'AAPL'  # Ticker symbol for Apple Inc.
# df = data.DataReader(symbol, "av-daily", start=datetime(2017, 2, 9),
#                     end=datetime(2024, 2, 26),
#                     api_key=key)

# %% [markdown]
# # We will try to normalize the values without calculating the returns. It just for the demonstration to see how it will be difficult for the LSTM model to learn effectively

# %% [markdown]
# # Let's plot raw closing data 1st

# %%
df['Close'].plot()
plt.show()

# %% [markdown]
# # Now we will normalize it without making the data stationary

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df_test = df.copy()
scaled_data = scaler.fit_transform(df_test[['Open', 'High', 'Low', 'Close','Volume']])
plt.plot(scaled_data[:, 3])

# %% [markdown]
# # Create Various columns with indicators based on pandas_ta  library. It is deterministic approach and we will use binary output as features. After experimentation it doesn't work well since it's too simple for deep neural networks and they memorize the training data

# %%
# df['sma_small_delta'] = np.where(df.ta.sma(length=5) > df.ta.sma(length=10),1,0)
# df['wma_small_delta'] = np.where(df.ta.wma(length=10) > df.ta.wma(length=20),1,0)
# df['sma_long_delta'] = np.where(df.ta.sma(length=20) > df.ta.sma(length=50),1,0)
# df['rsi_delta'] = np.where(df.ta.rsi(length=7) > df.ta.rsi(length=14),1,0)
# df['vwma_small_delta'] = np.where(df.ta.vwma(length=5) > df.ta.vwma(length=10),1,0)
# df['vwma_long_delta'] = np.where(df.ta.vwma(length=10) > df.ta.vwma(length=20),1,0)
#df['percent_return_20'] = df.ta.percent_return(length=20)
# df_vortex = df.ta.vortex(length=14)  # Vortex indicator has two oscillators positive and negative. We calculate the delta
# df_vortex['plus_delta'] = np.where(df_vortex['VTXP_14'] > df_vortex['VTXM_14'],1,0)
# df['vortex_plus_delta'] = df_vortex['plus_delta']

# %% [markdown]
# # Create columns based on pandas_ta library, non binary method that is more noise but more opportunities to learn the pattern

# %%
import pandas_ta as ta
df['sma_small_delta'] = (df.ta.sma(length=5) - df.ta.sma(length=10))/df.ta.sma(length=10)
df['wma_small_delta'] = (df.ta.wma(length=10) - df.ta.wma(length=20))/df.ta.wma(length=20)
df['sma_long_delta'] = (df.ta.sma(length=20) - df.ta.sma(length=50))/df.ta.sma(length=50)
df['rsi_delta'] = (df.ta.rsi(length=7) - df.ta.rsi(length=14)) / df.ta.rsi(length=14)
df['vwma_small_delta'] = (df.ta.vwma(length=5) - df.ta.vwma(length=10))/df.ta.vwma(length=10) # Volume weighted moving average
df['vwma_long_delta'] = (df.ta.vwma(length=10) - df.ta.vwma(length=20))/df.ta.vwma(length=20)
df['percent_return_20'] = df.ta.percent_return(length=20)
# vortex as has a skew so we ommited
# df_vortex = df.ta.vortex(length=14)  # Vortex indicator has two oscillators positive and negative. We calculate the delta
# df_vortex['plus_delta'] = (df_vortex['VTXP_14'] - df_vortex['VTXM_14'])/df_vortex['VTXM_14']
# df['vortex_plus_delta'] = df_vortex['plus_delta']
df['atr'] = df.ta.atr()/df['Close']
df['roc5'] = df.ta.roc(length=5)
df['roc'] = df.ta.roc()
df= df.dropna()

# %% [markdown]
# # plot any one indicator to confirm stationary properties

# %%
df[['sma_small_delta']].tail(200).plot() # Zoom in view to see if there is randomness or some cyclical pattern
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Now we will normalize the data that is the indicators we just created so it will have a similar scale

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
print(df.columns.to_list())
# Out:
# ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'sma_small_delta', 'wma_small_delta', 'sma_long_delta', 'rsi_delta', 'vwma_small_delta', 'vwma_long_delta', 'percent_return_20', 'atr', 'roc5', 'roc']

# %%
columns_to_norm = ['sma_small_delta', 'wma_small_delta', 'sma_long_delta', 'rsi_delta', 'vwma_small_delta', 'vwma_long_delta', 'percent_return_20', 'atr', 'roc5', 'roc']
#columns_to_norm = ['All_Candle_Patterns']

for col in columns_to_norm:
    df[[col]] = scaler.fit_transform(df[[col]])
# Out:
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\1369944331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[col]] = scaler.fit_transform(df[[col]])
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\1369944331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[col]] = scaler.fit_transform(df[[col]])
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\1369944331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[col]] = scaler.fit_transform(df[[col]])
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\1369944331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[col]] = scaler.fit_transform(df[[col]])
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\1369944331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[col]] = scaler.fit_transform(df[[col]])
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\1369944331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[col]] = scaler.fit_transform(df[[col]])
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\1369944331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[col]] = scaler.fit_transform(df[[col]])
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\1369944331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[col]] = scaler.fit_transform(df[[col]])
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\1369944331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[col]] = scaler.fit_transform(df[[col]])
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\1369944331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[col]] = scaler.fit_transform(df[[col]])

# %% [markdown]
# ## experiment #1
# create binary target if tomorrow's close is higher than today's close then assign the value one else assign the value 0

# %%
# df['next_day_close'] = df['Close'].shift(-1)
# df['target'] = (df['next_day_close'] > df['Close']).astype(int)

# %% [markdown]
# # Experiment #2
# Create 5 day SMA, And if tomorrow's close is higher than five days mean including current days close then assign the value one is assign the value 0 for for target

# %%
# df['next_day_close'] = df['Close'].shift(-1)
# df['5sma_lag'] = df['Close'].rolling(5).mean()
# df['target'] = (df['next_day_close'] > df['5sma_lag']).astype(int)
# 
# df = df.dropna()
# Out:
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\2887755221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['next_day_close'] = df['Close'].shift(-1)
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\2887755221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['5sma_lag'] = df['Close'].rolling(5).mean()
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\2887755221.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'] = (df['next_day_close'] > df['5sma_lag']).astype(int)

# %% [markdown]
# # Experiment #3
# If next 5 days simple moving average is higher than current five days simple moving average then assign the value one else assign the value 0 for target

# %%
df['5sma_lag'] = df['Close'].rolling(5).mean()
df['5sma_next'] = df['5sma_lag'].shift(-5)

df['target'] = (df['5sma_next'] > df['5sma_lag']).astype(int)

df = df.dropna()
# Out:
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\280214040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['5sma_lag'] = df['Close'].rolling(5).mean()
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\280214040.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['5sma_next'] = df['5sma_lag'].shift(-5)
# C:\Users\alex1\AppData\Local\Temp\ipykernel_17236\280214040.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'] = (df['5sma_next'] > df['5sma_lag']).astype(int)

# %% [markdown]
# # drop unwanted columns

# %%
df = df.drop(['Open', 'High','Low', 'Close', 'Adj Close', 'Volume','5sma_lag','5sma_next'],axis=1)
# df = df.drop(['Open', 'High','Low', 'Close', 'Adj Close', 'Volume','5sma_lag','next_day_close'],axis=1)

# df = df.drop(['Open', 'High','Low', 'Close', 'Adj Close', 'Volume','next_day_close'],axis=1)

# %%
df = df.dropna()

# %% [markdown]
# # Create target and features

# %%
features = df.drop('target', axis=1).values
target = df['target'].values

# %% [markdown]
# Create the sequence of length 10 for LSTM model

# %%
def create_sequences(features, target, sequence_length):
    X = []
    y = []
    for i in range(len(features) - sequence_length):
        X.append(features[i:i+sequence_length])
        y.append(target[i+(sequence_length-1)])
    return np.array(X), np.array(y)

sequence_length = 10
X, y = create_sequences(features, target, sequence_length)

# %% [markdown]
# # split X and Y into training and validation sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.4,shuffle=False)

# %%
print("Training shape:", X_train.shape)
print("Validation shape:", X_val.shape)
# Out:
# Training shape: (1632, 10, 10)
# Validation shape: (1089, 10, 10)

# %%
num_features = X_train.shape[2]
print(num_features)
# Out:
# 10

# %%
from keras.optimizers import Adam
from keras.regularizers import l1_l2,l1,l2
from keras.layers import LeakyReLU
# inputs = Input(shape=(sequence_length, X_train.sha))  # Replace with appropriate values


# Build the LSTM model
model = Sequential()
# model.add(LSTM(64, return_sequences=True, input_shape=(sequence_length, num_features), activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))
#model.add(LSTM(64, return_sequences=True, input_shape=(sequence_length, num_features), activation='relu', kernel_regularizer=l1(0.001)))
# model.add(LSTM(152, return_sequences=True, activation='relu'))  # Add an extra LSTM layer
#model.add(Dropout(0.5))
#model.add(LSTM(92, return_sequences=True, activation='relu'))  # Add an extra LSTM layer
#model.add(Dropout(0.4))
model.add(LSTM(32, return_sequences=True, activation='relu',input_shape=(sequence_length, num_features) ))  # Add an extra LSTM layer
# # model.add(Dropout(0.4))
# model.add(LSTM(32, return_sequences=True, activation='relu'))  # Add an extra LSTM layer
# # model.add(Dropout(0.4))
# model.add(LSTM(8, return_sequences=True, activation='tanh'))  # Add an extra LSTM layer
# # # model.add(Dropout(0.4))
model.add(LSTM(8))  # Add an extra LSTM layer
# model.add(Dense(1, activation='sigmoid',  kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))
model.add(Dense(1, activation='sigmoid'))
optimizer = Adam(learning_rate=0.001) # default is 0.001
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
early_stopping = EarlyStopping(monitor='val_loss',    # Monitor the val loss
                               patience=150,           # Num epochs; if no improvement training will be stopped
                               verbose=1,
                               mode='min',            # The training will stop when the quantity monitored has stopped decreasing
                               restore_best_weights=True) # Restores model weights from the epoch with the best value of the monitored quantity.

# %%
# Model checkpoint callback
model_checkpoint = ModelCheckpoint('/content/best_model.keras',   # Path where to save the model
                                   monitor='val_loss',   # Monitor the validation loss
                                   save_best_only=True,  # The latest best model according to the quantity monitored will not be overwritten
                                   mode='min',           # The training will save the model when the quantity monitored has decreased
                                   verbose=1)

# %%
from livelossplot import PlotLossesKeras
plot_losses = PlotLossesKeras()

# %%
model.fit(X_train, y_train,
                    epochs=1000,
                    batch_size=4,
                    validation_data=(X_val, y_val),
                    callbacks=[early_stopping, model_checkpoint,plot_losses],
                    verbose=False)
# Out:
# accuracy
# 	training         	 (min:    0.583, max:    0.730, cur:    0.724)
# 	validation       	 (min:    0.612, max:    0.727, cur:    0.720)
# Loss
# 	training         	 (min:    0.554, max:    0.679, cur:    0.554)
# 	validation       	 (min:    0.558, max:    0.673, cur:    0.572)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 model.fit(X_train, y_train,
#       2                     epochs=1000,
#       3                     batch_size=4,
#       4                     validation_data=(X_val, y_val),
#       5                     callbacks=[early_stopping, model_checkpoint,plot_losses],
#       6                     verbose=False)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\backend\torch\trainer.py:249, in TorchTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     245 for step, data in epoch_iterator.enumerate_epoch():
#     246     # Callbacks
#     247     callbacks.on_train_batch_begin(step)
# --> 249     logs = self.train_function(data)
#     251     # Callbacks
#     252     callbacks.on_train_batch_end(step, self._pythonify_logs(logs))
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\backend\torch\trainer.py:112, in TorchTrainer.make_train_function.<locals>.one_step_on_data(data)
#     110 """Runs a single training step on a batch of data."""
#     111 data = data[0]
# --> 112 return self.train_step(data)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\backend\torch\trainer.py:43, in TorchTrainer.train_step(self, data)
#      41 # Compute predictions
#      42 if self._call_has_training_arg:
# ---> 43     y_pred = self(x, training=True)
#      44 else:
#      45     y_pred = self(x)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\layers\layer.py:816, in Layer.__call__(self, *args, **kwargs)
#     814         outputs = super().__call__(*args, **kwargs)
#     815 else:
# --> 816     outputs = super().__call__(*args, **kwargs)
#     817 # Change the layout for the layer output if needed.
#     818 # This is useful for relayout intermediate tensor in the model
#     819 # to achieve the optimal performance.
#     820 distribution = distribution_lib.distribution()
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\backend\torch\layer.py:26, in TorchLayer.forward(self, *args, **kwargs)
#      25 def forward(self, *args, **kwargs):
# ---> 26     return Operation.__call__(self, *args, **kwargs)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\ops\operation.py:42, in Operation.__call__(self, *args, **kwargs)
#      37         call_fn = self.call
#      38     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      39         call_fn,
#      40         object_name=(f"{self.__class__.__name__}.call()"),
#      41     )
# ---> 42     return call_fn(*args, **kwargs)
#      44 # Plain flow.
#      45 if any_symbolic_tensors(args, kwargs):
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\utils\traceback_utils.py:157, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     155 bound_signature = None
#     156 try:
# --> 157     return fn(*args, **kwargs)
#     158 except Exception as e:
#     159     if hasattr(e, "_keras_call_info_injected"):
#     160         # Only inject info for the innermost failing call
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\models\sequential.py:203, in Sequential.call(self, inputs, training, mask)
#     201 def call(self, inputs, training=None, mask=None):
#     202     if self._functional:
# --> 203         return self._functional.call(inputs, training=training, mask=mask)
#     205     # Fallback: Just apply the layer sequence.
#     206     # This typically happens if `inputs` is a nested struct.
#     207     for layer in self.layers:
#     208         # During each iteration, `inputs` are the inputs to `layer`, and
#     209         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     210         # end of each iteration `inputs` is set to `outputs` to prepare for
#     211         # the next layer.
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\models\functional.py:188, in Functional.call(self, inputs, training, mask)
#     186         if mask is not None:
#     187             x._keras_mask = mask
# --> 188 outputs = self._run_through_graph(
#     189     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     190 )
#     191 return unpack_singleton(outputs)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\ops\function.py:153, in Function._run_through_graph(self, inputs, operation_fn)
#     150     continue  # Node is not computable, try skipping.
#     152 args, kwargs = node.arguments.fill_in(tensor_dict)
# --> 153 outputs = operation_fn(node.operation)(*args, **kwargs)
#     155 # Update tensor_dict.
#     156 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\models\functional.py:572, in operation_fn.<locals>.call(*args, **kwargs)
#     566 if (
#     567     hasattr(operation, "_call_has_training_arg")
#     568     and operation._call_has_training_arg
#     569     and training is not None
#     570 ):
#     571     kwargs["training"] = training
# --> 572 return operation(*args, **kwargs)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\layers\layer.py:816, in Layer.__call__(self, *args, **kwargs)
#     814         outputs = super().__call__(*args, **kwargs)
#     815 else:
# --> 816     outputs = super().__call__(*args, **kwargs)
#     817 # Change the layout for the layer output if needed.
#     818 # This is useful for relayout intermediate tensor in the model
#     819 # to achieve the optimal performance.
#     820 distribution = distribution_lib.distribution()
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\backend\torch\layer.py:26, in TorchLayer.forward(self, *args, **kwargs)
#      25 def forward(self, *args, **kwargs):
# ---> 26     return Operation.__call__(self, *args, **kwargs)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\ops\operation.py:42, in Operation.__call__(self, *args, **kwargs)
#      37         call_fn = self.call
#      38     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      39         call_fn,
#      40         object_name=(f"{self.__class__.__name__}.call()"),
#      41     )
# ---> 42     return call_fn(*args, **kwargs)
#      44 # Plain flow.
#      45 if any_symbolic_tensors(args, kwargs):
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\utils\traceback_utils.py:157, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     155 bound_signature = None
#     156 try:
# --> 157     return fn(*args, **kwargs)
#     158 except Exception as e:
#     159     if hasattr(e, "_keras_call_info_injected"):
#     160         # Only inject info for the innermost failing call
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\layers\rnn\lstm.py:538, in LSTM.call(self, sequences, initial_state, mask, training)
#     537 def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 538     return super().call(
#     539         sequences, mask=mask, training=training, initial_state=initial_state
#     540     )
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\layers\rnn\rnn.py:397, in RNN.call(self, sequences, initial_state, mask, training)
#     393 # Prepopulate the dropout state so that the inner_loop is stateless
#     394 # this is particularly important for JAX backend.
#     395 self._maybe_config_dropout_masks(self.cell, sequences, initial_state)
# --> 397 last_output, outputs, states = self.inner_loop(
#     398     sequences=sequences,
#     399     initial_state=initial_state,
#     400     mask=mask,
#     401     training=training,
#     402 )
#     403 last_output = ops.cast(last_output, self.compute_dtype)
#     404 outputs = ops.cast(outputs, self.compute_dtype)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\layers\rnn\lstm.py:533, in LSTM.inner_loop(self, sequences, initial_state, mask, training)
#     531     except NotImplementedError:
#     532         pass
# --> 533 return super().inner_loop(
#     534     sequences, initial_state, mask=mask, training=training
#     535 )
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\layers\rnn\rnn.py:339, in RNN.inner_loop(self, sequences, initial_state, mask, training)
#     336 if not tree.is_nested(initial_state):
#     337     initial_state = [initial_state]
# --> 339 return backend.rnn(
#     340     step,
#     341     sequences,
#     342     initial_state,
#     343     go_backwards=self.go_backwards,
#     344     mask=mask,
#     345     unroll=self.unroll,
#     346     input_length=sequences.shape[1],
#     347     zero_output_for_mask=self.zero_output_for_mask,
#     348     return_all_outputs=self.return_sequences,
#     349 )
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\backend\torch\rnn.py:346, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     344 new_states = states
#     345 while time < time_steps_t and it < max_iterations:
# --> 346     final_outputs = _step(time, output_ta_t, *new_states)
#     347     time, output_ta_t = final_outputs[:2]
#     348     new_states = final_outputs[2:]
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\backend\torch\rnn.py:329, in rnn.<locals>._step(time, output_ta_t, *states)
#     327 current_input = tuple(ta[time] for ta in input_ta)
#     328 current_input = pack_sequence_as(inputs, current_input)
# --> 329 output, new_states = step_function(
#     330     current_input, tuple(states) + tuple(constants)
#     331 )
#     332 flat_new_state = tree.flatten(new_states)
#     334 flat_output = tree.flatten(output)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\layers\rnn\rnn.py:331, in RNN.inner_loop.<locals>.step(inputs, states)
#     330 def step(inputs, states):
# --> 331     output, new_states = self.cell(inputs, states, **cell_kwargs)
#     332     if not tree.is_nested(new_states):
#     333         new_states = [new_states]
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\layers\layer.py:816, in Layer.__call__(self, *args, **kwargs)
#     814         outputs = super().__call__(*args, **kwargs)
#     815 else:
# --> 816     outputs = super().__call__(*args, **kwargs)
#     817 # Change the layout for the layer output if needed.
#     818 # This is useful for relayout intermediate tensor in the model
#     819 # to achieve the optimal performance.
#     820 distribution = distribution_lib.distribution()
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\backend\torch\layer.py:26, in TorchLayer.forward(self, *args, **kwargs)
#      25 def forward(self, *args, **kwargs):
# ---> 26     return Operation.__call__(self, *args, **kwargs)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\ops\operation.py:42, in Operation.__call__(self, *args, **kwargs)
#      37         call_fn = self.call
#      38     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      39         call_fn,
#      40         object_name=(f"{self.__class__.__name__}.call()"),
#      41     )
# ---> 42     return call_fn(*args, **kwargs)
#      44 # Plain flow.
#      45 if any_symbolic_tensors(args, kwargs):
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\utils\traceback_utils.py:157, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     155 bound_signature = None
#     156 try:
# --> 157     return fn(*args, **kwargs)
#     158 except Exception as e:
#     159     if hasattr(e, "_keras_call_info_injected"):
#     160         # Only inject info for the innermost failing call
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\layers\rnn\lstm.py:265, in LSTMCell.call(self, inputs, states, training)
#     263     c, o = self._compute_carry_and_output(x, h_tm1, c_tm1)
#     264 else:
# --> 265     z = ops.matmul(inputs, self.kernel)
#     267     z += ops.matmul(h_tm1, self.recurrent_kernel)
#     268     if self.use_bias:
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\ops\numpy.py:3547, in matmul(x1, x2)
#    3545 if any_symbolic_tensors((x1, x2)):
#    3546     return Matmul().symbolic_call(x1, x2)
# -> 3547 return backend.numpy.matmul(x1, x2)
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\backend\torch\numpy.py:47, in matmul(x1, x2)
#      46 def matmul(x1, x2):
# ---> 47     x1 = convert_to_tensor(x1)
#      48     x2 = convert_to_tensor(x2)
#      49     # When both x1 and x2 are of int8, we cast the outputs to int32 to align
#      50     # with jax
#      51     # TODO: Support hardware-accelerated matmul
#
# File D:\anaconda\envs\deeplearning\lib\site-packages\keras\src\backend\torch\core.py:164, in convert_to_tensor(x, dtype, sparse)
#     162 device = get_device()
#     163 if x.device != device:
# --> 164     x = x.to(device)
#     165 if dtype is None:
#     166     return x
#
# KeyboardInterrupt:

# %% [markdown]
# #plot model architecture

# %%
plot_model(model, to_file='lstm_model.png', show_shapes=True, show_layer_names=True)
